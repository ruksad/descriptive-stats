# %% [markdown]
# # Machine Learning Questions
#
# This notebook contains comprehensive questions covering various Machine Learning topics taught in the course.

# %% [markdown]
# ## Section 1: Clustering - Conceptual Questions [10 marks]
#
# 1. What is the main difference between supervised and unsupervised learning? Give two examples of each.
#
# 2. Explain the K-Means clustering algorithm. What are the steps involved in the algorithm?
#
# 3. What is the "elbow method" in K-Means clustering? How does it help in determining the optimal number of clusters?
#
# 4. What are the limitations of K-Means clustering? Name at least three.
#
# 5. What is the difference between inertia and silhouette score? Which one is better for evaluating clustering quality?
#
# 6. What is hierarchical clustering? How is it different from K-Means?
#
# 7. Explain the concept of DBSCAN clustering. What are its advantages over K-Means?
#
# 8. What is the curse of dimensionality and how does it affect clustering algorithms?
#
# 9. How would you handle categorical features when performing clustering?
#
# 10. What preprocessing steps should be performed before applying K-Means clustering?

# %% [markdown]
# ## Section 2: Clustering - Practical Questions [15 marks]
#
# 1. Load the Iris dataset from scikit-learn and perform K-Means clustering with k=3. Calculate the inertia and silhouette score.
#
# 2. Plot the elbow curve for the Iris dataset using K values from 2 to 10.
#
# 3. Visualize the clusters obtained from K-Means on the Iris dataset using a scatter plot.
#
# 4. Compare the clustering results with the actual labels. Calculate the accuracy using appropriate metrics.
#
# 5. Implement a function to standardize features before clustering and show the impact on clustering quality.

# %%
# Code cell for practical clustering questions
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# Your solutions here

# %% [markdown]
# ## Section 3: Linear Regression - Conceptual Questions [10 marks]
#
# 1. What is linear regression? What assumptions does it make about the data?
#
# 2. Explain the difference between simple linear regression and multiple linear regression.
#
# 3. What is the cost function (loss function) used in linear regression? Write its mathematical formula.
#
# 4. Explain the concept of gradient descent. How is it used to optimize linear regression?
#
# 5. What is R-squared (R²)? How do you interpret it?
#
# 6. What is the difference between R² and Adjusted R²?
#
# 7. What is multicollinearity? How does it affect linear regression models?
#
# 8. What is regularization in linear regression? Explain Ridge (L2) and Lasso (L1) regularization.
#
# 9. What is the difference between training error and test error? Why is cross-validation important?
#
# 10. How do you detect and handle outliers in linear regression?

# %% [markdown]
# ## Section 4: Linear Regression - Practical Questions [15 marks]
#
# 1. Create a simple linear regression model to predict car prices based on mileage. Generate sample data or use the car_data.csv if available.
#
# 2. Split your dataset into training (80%) and testing (20%) sets. Train the model and evaluate it using MSE, RMSE, and R².
#
# 3. Create a scatter plot showing the actual vs. predicted values along with the regression line.
#
# 4. Implement multiple linear regression with at least 3 features. Compare the performance with simple linear regression.
#
# 5. Apply Ridge and Lasso regularization to your model and compare the results.

# %%
# Code cell for practical linear regression questions
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# Your solutions here

# %% [markdown]
# ## Section 5: Feature Engineering & Encoding - Conceptual Questions [10 marks]
#
# 1. What is feature engineering? Why is it important in machine learning?
#
# 2. Explain the following encoding techniques:
#    - Label Encoding
#    - One-Hot Encoding
#    - Ordinal Encoding
#    - Target Encoding
#
# 3. When would you use One-Hot Encoding vs. Label Encoding?
#
# 4. What is the dummy variable trap? How do you avoid it?
#
# 5. What is feature scaling? Explain the difference between normalization and standardization.
#
# 6. What is feature selection? Name three techniques for feature selection.
#
# 7. What are interaction features? Give an example of when they might be useful.
#
# 8. Explain the concept of polynomial features. When would you use them?
#
# 9. What is the purpose of feature extraction techniques like PCA?
#
# 10. How do you handle missing values in categorical and numerical features?

# %% [markdown]
# ## Section 6: Feature Engineering - Practical Questions [10 marks]
#
# 1. Create a dataset with categorical variables and apply different encoding techniques (Label, One-Hot, Ordinal).
#
# 2. Compare the performance of a machine learning model before and after feature scaling.
#
# 3. Create polynomial features from a dataset and observe the impact on model performance.
#
# 4. Implement a function to handle missing values using different imputation strategies.
#
# 5. Use category_encoders library to implement Target Encoding on a dataset.

# %%
# Code cell for practical feature engineering questions
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler, MinMaxScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.impute import SimpleImputer
import category_encoders as ce

# Your solutions here

# %% [markdown]
# ## Section 7: Classification - Conceptual Questions [10 marks]
#
# 1. What is classification in machine learning? How is it different from regression?
#
# 2. Explain the following classification algorithms:
#    - Logistic Regression
#    - Decision Trees
#    - Random Forest
#    - Support Vector Machines (SVM)
#    - K-Nearest Neighbors (KNN)
#
# 3. What is a confusion matrix? Explain True Positive, True Negative, False Positive, and False Negative.
#
# 4. Define the following metrics and explain when to use each:
#    - Accuracy
#    - Precision
#    - Recall
#    - F1-Score
#
# 5. What is the ROC curve and AUC? How do you interpret them?
#
# 6. What is the difference between binary and multi-class classification?
#
# 7. What is overfitting and underfitting? How do you detect and prevent them?
#
# 8. Explain cross-validation. What is k-fold cross-validation?
#
# 9. What is class imbalance? Name three techniques to handle imbalanced datasets.
#
# 10. What is the bias-variance tradeoff in machine learning?

# %% [markdown]
# ## Section 8: Classification - Practical Questions [15 marks]
#
# 1. Load a classification dataset (e.g., Iris, breast cancer) and build a Logistic Regression model.
#
# 2. Calculate and display the confusion matrix for your classification model.
#
# 3. Compute Accuracy, Precision, Recall, and F1-Score for your model.
#
# 4. Plot the ROC curve and calculate the AUC score.
#
# 5. Implement k-fold cross-validation (k=5) and report the mean accuracy.
#
# 6. Build a Decision Tree classifier and visualize the tree.
#
# 7. Compare the performance of at least three different classification algorithms on the same dataset.

# %%
# Code cell for practical classification questions
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, roc_auc_score
from sklearn.model_selection import cross_val_score

# Your solutions here

# %% [markdown]
# ## Section 9: Text Processing & NLP - Conceptual Questions [10 marks]
#
# 1. What is text preprocessing? List five common preprocessing steps.
#
# 2. Explain the following NLP concepts:
#    - Tokenization
#    - Stemming
#    - Lemmatization
#    - Stop words
#
# 3. What is Bag of Words (BoW)? What are its advantages and disadvantages?
#
# 4. What is TF-IDF? How is it different from Bag of Words?
#
# 5. What are word embeddings? Explain Word2Vec and its variants (CBOW and Skip-gram).
#
# 6. What is the difference between Word2Vec and GloVe?
#
# 7. What are document embeddings? How is Doc2Vec different from Word2Vec?
#
# 8. What is the purpose of padding in text processing for neural networks?
#
# 9. What is named entity recognition (NER)?
#
# 10. What is sentiment analysis? Name three approaches to perform sentiment analysis.

# %% [markdown]
# ## Section 10: Text Processing - Practical Questions [15 marks]
#
# 1. Create a sample text corpus and perform basic preprocessing (lowercasing, removing punctuation, tokenization).
#
# 2. Implement Bag of Words using CountVectorizer from scikit-learn.
#
# 3. Implement TF-IDF vectorization and compare it with BoW on a text classification task.
#
# 4. Train a Word2Vec model using gensim on a text corpus.
#
# 5. Find similar words using your trained Word2Vec model.
#
# 6. Build a simple text classifier using TF-IDF features and Logistic Regression.

# %%
# Code cell for practical NLP questions
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# Download required NLTK data
# nltk.download('punkt')
# nltk.download('stopwords')
# nltk.download('wordnet')

# Your solutions here

# %% [markdown]
# ## Section 11: Model Evaluation & Validation - Conceptual Questions [10 marks]
#
# 1. What is the purpose of splitting data into training, validation, and test sets?
#
# 2. What is cross-validation? Explain different types of cross-validation strategies.
#
# 3. What is grid search and random search for hyperparameter tuning?
#
# 4. What is the learning curve? How can it help in diagnosing model performance?
#
# 5. What is early stopping in machine learning?
#
# 6. What is the difference between parametric and non-parametric models?
#
# 7. What is ensemble learning? Explain bagging and boosting.
#
# 8. What is feature importance? How can you calculate it for tree-based models?
#
# 9. What is a baseline model? Why is it important to establish one?
#
# 10. What is the difference between online learning and batch learning?

# %% [markdown]
# ## Section 12: Advanced Topics - Conceptual Questions [10 marks]
#
# 1. What is dimensionality reduction? Why is it important?
#
# 2. Explain Principal Component Analysis (PCA). What does it do?
#
# 3. What is t-SNE? How is it different from PCA?
#
# 4. What is the difference between generative and discriminative models?
#
# 5. What is transfer learning? Give an example of its application.
#
# 6. What is anomaly detection? Name two techniques for anomaly detection.
#
# 7. What is reinforcement learning? How is it different from supervised learning?
#
# 8. What is the difference between batch normalization and layer normalization?
#
# 9. What is the vanishing gradient problem in neural networks?
#
# 10. What is AutoML? What are its benefits and limitations?

# %% [markdown]
# ## Section 13: Case Study Questions [20 marks]
#
# ### Case Study 1: Customer Segmentation
# You are working for an e-commerce company that wants to segment its customers for targeted marketing.
#
# 1. What type of machine learning approach would you use? Why?
# 2. What features would you consider for customer segmentation?
# 3. How would you determine the optimal number of segments?
# 4. How would you validate your segmentation results?
# 5. How would you present the findings to non-technical stakeholders?
#
# ### Case Study 2: Fraud Detection
# You need to build a fraud detection system for credit card transactions.
#
# 1. What challenges would you expect with this dataset?
# 2. How would you handle class imbalance (fraudulent transactions are rare)?
# 3. Which evaluation metric would be most important: Precision or Recall? Why?
# 4. What features would be relevant for fraud detection?
# 5. How would you deploy and monitor this model in production?
#
# ### Case Study 3: House Price Prediction
# You are building a model to predict house prices based on various features.
#
# 1. What type of problem is this? What algorithms would you consider?
# 2. How would you handle categorical features like neighborhood or house style?
# 3. How would you detect and handle outliers in house prices?
# 4. What feature engineering techniques might improve your model?
# 5. How would you explain your model's predictions to users?
#
# ### Case Study 4: Sentiment Analysis of Product Reviews
# You need to build a sentiment analysis system for product reviews.
#
# 1. What preprocessing steps would you apply to the text data?
# 2. Would you use Bag of Words, TF-IDF, or Word Embeddings? Justify your choice.
# 3. What classification algorithm would you start with?
# 4. How would you handle neutral sentiments?
# 5. How would you evaluate the performance of your sentiment analysis model?

# %% [markdown]
# ## Section 14: Practical Implementation Project [30 marks]
#
# Choose one of the following projects and implement a complete solution:
#
# ### Project Option A: End-to-End Classification Pipeline
# 1. Load a real-world classification dataset (e.g., from Kaggle or UCI ML Repository)
# 2. Perform Exploratory Data Analysis (EDA)
# 3. Handle missing values and outliers
# 4. Perform feature engineering and encoding
# 5. Split data and train multiple models
# 6. Perform hyperparameter tuning
# 7. Evaluate models using appropriate metrics
# 8. Select the best model and explain your choice
# 9. Create visualizations of your results
# 10. Write a summary of your findings
#
# ### Project Option B: Clustering Analysis with Visualization
# 1. Load a dataset suitable for clustering (e.g., customer data, image data)
# 2. Perform preprocessing and feature scaling
# 3. Apply multiple clustering algorithms (K-Means, Hierarchical, DBSCAN)
# 4. Determine optimal number of clusters using multiple methods
# 5. Evaluate clustering quality using silhouette score and other metrics
# 6. Visualize clusters using dimensionality reduction (PCA, t-SNE)
# 7. Interpret and profile each cluster
# 8. Compare different clustering algorithms
# 9. Provide actionable insights from the clustering
# 10. Create a comprehensive report with visualizations
#
# ### Project Option C: Text Classification System
# 1. Collect or load a text classification dataset
# 2. Perform text preprocessing (cleaning, tokenization, etc.)
# 3. Implement multiple text vectorization techniques (BoW, TF-IDF, Word2Vec)
# 4. Train multiple classifiers with each vectorization method
# 5. Compare model performances
# 6. Perform error analysis on misclassified examples
# 7. Implement a simple ensemble method
# 8. Create a function to predict on new text inputs
# 9. Visualize important words/features for each class
# 10. Document your complete pipeline

# %%
# Code cell for the practical implementation project
# Import all necessary libraries

# Your complete solution here

# %% [markdown]
# ## Bonus Section: Debugging & Troubleshooting [5 marks]
#
# **Note:** Each of the following code snippets contains one or more errors. Identify the errors and provide corrected code.
#
# Identify and fix the errors in the following code snippets:
#
# ### Question 1:
# ```python
# from sklearn.cluster import KMeans
# from sklearn.datasets import load_iris
#
# iris = load_iris()
# X = iris.data
#
# kmeans = KMeans(n_clusters=3)
# predictions = kmeans.predict(X)
# ```
#
# ### Question 2:
# ```python
# from sklearn.linear_model import LinearRegression
# from sklearn.model_selection import train_test_split
#
# X = [[1], [2], [3], [4], [5]]
# y = [2, 4, 6, 8, 10]
#
# X_train, X_test, y_train, y_test = train_test_split(X, y)
# model = LinearRegression()
# model.fit(X_train, y_train)
# score = model.score(X_test)
# ```
#
# ### Question 3:
# ```python
# from sklearn.preprocessing import StandardScaler
#
# X_train = [[1, 2], [3, 4], [5, 6]]
# X_test = [[7, 8], [9, 10]]
#
# scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train)
# X_test_scaled = scaler.fit_transform(X_test)
# ```
#
# ### Question 4:
# ```python
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.datasets import load_iris
#
# iris = load_iris()
# X, y = iris.data, iris.target
#
# model = RandomForestClassifier(random_state=42)
# model.fit(X, y)
# accuracy = model.score(X, y)
# print(f"Model accuracy: {accuracy}")
# ```
#
# ### Question 5:
# ```python
# from sklearn.feature_extraction.text import CountVectorizer
#
# corpus = ['This is document one', 'This is document two']
# vectorizer = CountVectorizer()
# X = vectorizer.transform(corpus)
# ```

# %%
# Your corrected code solutions here

# %% [markdown]
# ---
# ## Instructions for Students
#
# 1. Answer all conceptual questions clearly and concisely.
# 2. For practical questions, provide complete working code with comments.
# 3. Include visualizations where appropriate.
# 4. For case studies, provide detailed reasoning and justification for your choices.
# 5. For the implementation project, create a well-documented, complete solution.
# 6. Test your code before submission to ensure it runs without errors.
# 7. Use markdown cells to explain your approach and findings.
#
# **Total Marks: 200**
#
# Good luck!
